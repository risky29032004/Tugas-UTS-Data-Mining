# %% [markdown]
# <a href="https://colab.research.google.com/github/risky29032004/Tugas-UTS-Data-Mining/blob/main/UTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import zipfile

with zipfile.ZipFile('drive-download-20250505T143943Z-001.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
dataset1 = pd.read_csv("DDoS ICMP Flood.csv")

# %%
dataset
# Out:
#                                          Flow ID           Src IP  Src Port  \
# 0        54.164.8.26-192.168.137.174-443-50634-6      54.164.8.26       443
# 1     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 2     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 3        34.173.20.6-192.168.137.174-443-47304-6      34.173.20.6       443
# 4        192.168.137.174-34.173.20.6-47304-443-6  192.168.137.174     47304
# ...                                          ...              ...       ...
# 2547   54.204.30.230-192.168.137.221-443-43300-6    54.204.30.230       443
# 2548           10.0.0.13-10.0.0.254-35153-1883-6        10.0.0.13     35153
# 2549     192.168.137.210-35.82.26.14-41096-443-6  192.168.137.210     41096
# 2550           10.0.0.15-10.0.0.254-40499-1883-6        10.0.0.15     40499
# 2551    34.66.16.188-192.168.137.174-443-40866-6     34.66.16.188       443
#
# ...

# %%
dataset2 = pd.read_csv("DDoS UDP Flood.csv")

# %%
dataset
# Out:
#                                          Flow ID           Src IP  Src Port  \
# 0        54.164.8.26-192.168.137.174-443-50634-6      54.164.8.26       443
# 1     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 2     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 3        34.173.20.6-192.168.137.174-443-47304-6      34.173.20.6       443
# 4        192.168.137.174-34.173.20.6-47304-443-6  192.168.137.174     47304
# ...                                          ...              ...       ...
# 2547   54.204.30.230-192.168.137.221-443-43300-6    54.204.30.230       443
# 2548           10.0.0.13-10.0.0.254-35153-1883-6        10.0.0.13     35153
# 2549     192.168.137.210-35.82.26.14-41096-443-6  192.168.137.210     41096
# 2550           10.0.0.15-10.0.0.254-40499-1883-6        10.0.0.15     40499
# 2551    34.66.16.188-192.168.137.174-443-40866-6     34.66.16.188       443
#
# ...

# %%
dataset3 = pd.read_csv("DoS ICMP Flood.csv")

# %%
dataset
# Out:
#                                          Flow ID           Src IP  Src Port  \
# 0        54.164.8.26-192.168.137.174-443-50634-6      54.164.8.26       443
# 1     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 2     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 3        34.173.20.6-192.168.137.174-443-47304-6      34.173.20.6       443
# 4        192.168.137.174-34.173.20.6-47304-443-6  192.168.137.174     47304
# ...                                          ...              ...       ...
# 2547   54.204.30.230-192.168.137.221-443-43300-6    54.204.30.230       443
# 2548           10.0.0.13-10.0.0.254-35153-1883-6        10.0.0.13     35153
# 2549     192.168.137.210-35.82.26.14-41096-443-6  192.168.137.210     41096
# 2550           10.0.0.15-10.0.0.254-40499-1883-6        10.0.0.15     40499
# 2551    34.66.16.188-192.168.137.174-443-40866-6     34.66.16.188       443
#
# ...

# %%
hasilgabung =pd.concat([dataset,dataset2,dataset3],ignore_index=True)

# %%
hasilgabung.columns.values
# Out:
# array(['Flow ID', 'Src IP', 'Src Port', 'Dst IP', 'Dst Port', 'Protocol',
#        'Timestamp', 'Flow Duration', 'Total Fwd Packet',
#        'Total Bwd packets', 'Total Length of Fwd Packet',
#        'Total Length of Bwd Packet', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Bwd Packet Length Max',
#        'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow Packets/s',
#        'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min',
#        'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max',
#        'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean', 'Bwd IAT Std',
#        'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
# ...

# %%
x = hasilgabung.iloc[:,7: 76]

# %%
x
# Out:
#       Flow Duration  Total Fwd Packet  Total Bwd packets  \
# 0            386988                25                 42
# 1             18583                 3                  0
# 2            164448                 1                  3
# 3          59949896                 8                  3
# 4              1224                 4                  0
# ...             ...               ...                ...
# 7230      119992022                29                 28
# 7231      119995824                29                 28
# 7232      119991957                29                 28
# 7233      110033626                16                 16
# 7234      110032515                16                 16
#
#       Total Length of Fwd Packet  Total Length of Bwd Packet  \
# 0                         6094.0                     46123.0
# 1                           24.0                         0.0
# 2                            0.0                        24.0
# ...

# %%
y = hasilgabung.iloc[:,83: 84]

# %%
y
# Out:
#           Attack Name
# 0     DDoS ICMP Flood
# 1     DDoS ICMP Flood
# 2     DDoS ICMP Flood
# 3     DDoS ICMP Flood
# 4     DDoS ICMP Flood
# ...               ...
# 7230   DoS ICMP Flood
# 7231   DoS ICMP Flood
# 7232   DoS ICMP Flood
# 7233   DoS ICMP Flood
# 7234   DoS ICMP Flood
#
# [7235 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

# %%
alya = DecisionTreeClassifier(criterion='entropy', splitter = 'random')
alya.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', splitter='random')

# %%
y_pred = alya.predict(x_test)

# %%
y_pred
# Out:
# array(['DDoS UDP Flood', 'DDoS UDP Flood', 'DDoS ICMP Flood', ...,
#        'DDoS ICMP Flood', 'DDoS UDP Flood', 'DDoS ICMP Flood'],
#       dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)


rf.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
from sklearn.metrics import accuracy_score

y_pred = rf.predict(x_test)
print("Akurasi Random Forest:", accuracy_score(y_test, y_pred))
# Out:
# Akurasi Random Forest: 0.7387698686938493

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.figure(figsize = (10, 7))
tree.plot_tree(alya, feature_names = x.columns.values, class_names = np.array([ 'Benign Traffic','DDos ICMP Flood','DDoS UDP Flood']), filled = True)
plt.show()

# %%
import seaborn as lol
from sklearn import metrics
label = np.array([ 'DDoS ICMP Flood','DDos UDP Flood','DoS ICMP Flood'])

# %%
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
conf_matrix = metrics.confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Prediksi')
plt.ylabel('Fakta')
plt.show()

# %%
import pandas as pd

hasilgabung = pd.concat([dataset1, dataset2, dataset3], ignore_index=True)

jumlah_kolom = hasilgabung.shape[1]

tengah = jumlah_kolom // 2

kiri = hasilgabung.iloc[:, :tengah]
kanan = hasilgabung.iloc[:, tengah:]

# %%
print("DataFrame Gabungan:")
print(hasilgabung)
print("\n")

print("Bagian Kiri:")
print(kiri)
print("\n")

print("Bagian Kanan:")
print(kanan)
# Out:
# DataFrame Gabungan:
#                                          Flow ID           Src IP  Src Port  \
# 0        54.164.8.26-192.168.137.174-443-50634-6      54.164.8.26       443
# 1     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 2     13.225.193.148-192.168.137.174-443-39086-6   13.225.193.148       443
# 3        34.173.20.6-192.168.137.174-443-47304-6      34.173.20.6       443
# 4        192.168.137.174-34.173.20.6-47304-443-6  192.168.137.174     47304
# ...                                          ...              ...       ...
# 7230            10.0.0.9-10.0.0.254-45455-1883-6         10.0.0.9     45455
# 7231            10.0.0.9-10.0.0.254-35905-1883-6         10.0.0.9     35905
# 7232            10.0.0.8-10.0.0.254-43951-1883-6         10.0.0.8     43951
# 7233            10.0.0.6-10.0.0.254-35017-1883-6         10.0.0.6     35017
# 7234            10.0.0.6-10.0.0.254-44133-1883-6         10.0.0.6     44133
#
# ...

# %% [markdown]
# Dataset setelah digabung dan dibagi 2 sebelah kanan dan kiri
